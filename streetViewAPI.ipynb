# %%
import requests 
import json
import csv

payload = {'location': 'chicago', 'size': '600x400', "key":"AIzaSyAjU70AlRIkXgS07M5Dscj968Iapl9C0OE"}
r = requests.get('https://maps.googleapis.com/maps/api/streetview?', params=payload, stream=all)
#print(r.json())
#r.text

from IPython.display import Image, display
import PIL
i = Image(r.content)
display(i) 
with open("GoogleMap.jpg", "wb") as png:
    png.write(r.content)

# %%
#within object detection notebook
from PIL import Image
content = Image.open('GoogleMap.jpg') # actual path : '/content/GoogleMap.jpg'
display(content) 
#run_detector(detector, "/content/GoogleMap.jpg")
#load_img("/content/GoogleMap.jpg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x400 at 0x1E22ED04708>
